# %%
import os

def search_string_in_files(root_dir, target_string):
    # List to store paths of files containing the target string
    matching_files = []
    
    # Walk through all files and folders within root_dir
    for dirpath, _, filenames in os.walk(root_dir):
        for filename in filenames:
            file_path = os.path.join(dirpath, filename)
            try:
                # Open and read each file to search for the target string
                with open(file_path, 'r', encoding='utf-8') as file:
                    if target_string in file.read():
                        matching_files.append(file_path)
            except (UnicodeDecodeError, PermissionError) as e:
                # Skip files that can't be read as text or don't have permissions
                print(f"Skipping file {file_path}: {e}")
    
    # Print results
    if matching_files:
        print("Files containing the target string:")
        for file_path in matching_files:
            print(file_path)
    else:
        print("No files containing the target string were found.")

# Run the function in the current directory
search_string_in_files(".", "Hi, I am")
# Out:
# Skipping file .\.git\index: 'utf-8' codec can't decode byte 0xf8 in position 14: invalid start byte
# Skipping file .\.git\objects\41\ec9111199b0c6b7915eb8e348d06a0a13ef955: 'utf-8' codec can't decode byte 0x95 in position 2: invalid start byte
# Skipping file .\.git\objects\49\28de330362128d2930436efd6c46e2f83bd7dc: 'utf-8' codec can't decode byte 0xd1 in position 21: invalid continuation byte
# Skipping file .\.git\objects\7b\7876da3c230631bc1e483d5e41b1d1066de4d5: 'utf-8' codec can't decode byte 0xb0 in position 7: invalid start byte
# Skipping file .\.git\objects\91\3d0d5aee82da980d4dbb103671be1fbee324ca: 'utf-8' codec can't decode byte 0xb6 in position 20: invalid start byte
# Skipping file .\.git\objects\b7\638e53f0ae36a1709548c37413896047bff286: 'utf-8' codec can't decode byte 0x9c in position 2: invalid start byte
# Skipping file .\.git\objects\b9\0df5d7d8f477f3d69c74f80d9439ac60d5aab4: 'utf-8' codec can't decode byte 0x8d in position 2: invalid start byte
# Skipping file .\.git\objects\bc\de72a9e3c021f783488662045600b3b591426b: 'utf-8' codec can't decode byte 0xb0 in position 7: invalid start byte
# Skipping file .\.git\objects\f1\2dc478e547dc9f55b00fa944bd9af0a31276c8: 'utf-8' codec can't decode byte 0x95 in position 2: invalid start byte
# Skipping file .\.git\objects\pack\pack-1debc79a54bae61a456a3ba568167957062be717.idx: 'utf-8' codec can't decode byte 0xff in position 0: invalid start byte
# Skipping file .\.git\objects\pack\pack-1debc79a54bae61a456a3ba568167957062be717.pack: 'utf-8' codec can't decode byte 0x96 in position 12: invalid start byte
# Skipping file .\.git\objects\pack\pack-1debc79a54bae61a456a3ba568167957062be717.rev: 'utf-8' codec can't decode byte 0x9f in position 15: invalid start byte
# Skipping file .\assets\fonts\academicons.eot: 'utf-8' codec can't decode byte 0x94 in position 1: invalid start byte
# Skipping file .\assets\fonts\academicons.ttf: 'utf-8' codec can't decode byte 0x80 in position 7: invalid start byte
# Skipping file .\assets\fonts\academicons.woff: 'utf-8' codec can't decode byte 0x94 in position 10: invalid start byte
# Skipping file .\assets\fonts\fa-brands-400.eot: 'utf-8' codec can't decode byte 0xdc in position 0: invalid continuation byte
# Skipping file .\assets\fonts\fa-brands-400.ttf: 'utf-8' codec can't decode byte 0x80 in position 7: invalid start byte
# Skipping file .\assets\fonts\fa-brands-400.woff: 'utf-8' codec can't decode byte 0xcc in position 11: invalid continuation byte
# Skipping file .\assets\fonts\fa-brands-400.woff2: 'utf-8' codec can't decode byte 0xe8 in position 11: invalid continuation byte
# Skipping file .\assets\fonts\fa-regular-400.eot: 'utf-8' codec can't decode byte 0x9e in position 1: invalid start byte
# Skipping file .\assets\fonts\fa-regular-400.ttf: 'utf-8' codec can't decode byte 0x80 in position 7: invalid start byte
# Skipping file .\assets\fonts\fa-regular-400.woff: 'utf-8' codec can't decode byte 0xc0 in position 11: invalid start byte
# Skipping file .\assets\fonts\fa-regular-400.woff2: 'utf-8' codec can't decode byte 0xfc in position 11: invalid start byte
# Skipping file .\assets\fonts\fa-solid-900.eot: 'utf-8' codec can't decode byte 0x90 in position 28: invalid start byte
# Skipping file .\assets\fonts\fa-solid-900.ttf: 'utf-8' codec can't decode byte 0x80 in position 7: invalid start byte
# Skipping file .\assets\fonts\fa-solid-900.woff: 'utf-8' codec can't decode byte 0xcc in position 11: invalid continuation byte
# Skipping file .\assets\fonts\fa-solid-900.woff2: 'utf-8' codec can't decode byte 0xf2 in position 53: invalid continuation byte
# Skipping file .\files\paper1.pdf: 'utf-8' codec can't decode byte 0x9c in position 72: invalid start byte
# Skipping file .\files\paper2.pdf: 'utf-8' codec can't decode byte 0x9c in position 72: invalid start byte
# Skipping file .\files\paper3.pdf: 'utf-8' codec can't decode byte 0x9c in position 72: invalid start byte
# Skipping file .\images\3953273590_704e3899d5_m.jpg: 'utf-8' codec can't decode byte 0xff in position 0: invalid start byte
# Skipping file .\images\500x300.png: 'utf-8' codec can't decode byte 0x89 in position 0: invalid start byte
# Skipping file .\images\bio-photo-2.jpg: 'utf-8' codec can't decode byte 0xff in position 0: invalid start byte
# Skipping file .\images\bio-photo.jpg: 'utf-8' codec can't decode byte 0xff in position 0: invalid start byte
# Skipping file .\images\editing-talk.png: 'utf-8' codec can't decode byte 0x89 in position 0: invalid start byte
# Skipping file .\images\ESP32_system.png: 'utf-8' codec can't decode byte 0x89 in position 0: invalid start byte
# Skipping file .\images\foo-bar-identity-th.jpg: 'utf-8' codec can't decode byte 0xff in position 0: invalid start byte
# Skipping file .\images\foo-bar-identity.jpg: 'utf-8' codec can't decode byte 0xff in position 0: invalid start byte
# Skipping file .\images\image-alignment-1200x4002.jpg: 'utf-8' codec can't decode byte 0xff in position 0: invalid start byte
# Skipping file .\images\image-alignment-150x150.jpg: 'utf-8' codec can't decode byte 0xff in position 0: invalid start byte
# Skipping file .\images\image-alignment-300x200.jpg: 'utf-8' codec can't decode byte 0xff in position 0: invalid start byte
# Skipping file .\images\image-alignment-580x300.jpg: 'utf-8' codec can't decode byte 0xff in position 0: invalid start byte
# Skipping file .\images\mstile-144x144.png: 'utf-8' codec can't decode byte 0x89 in position 0: invalid start byte
# Skipping file .\images\mstile-150x150.png: 'utf-8' codec can't decode byte 0x89 in position 0: invalid start byte
# Skipping file .\images\mstile-310x150.png: 'utf-8' codec can't decode byte 0x89 in position 0: invalid start byte
# Skipping file .\images\mstile-310x310.png: 'utf-8' codec can't decode byte 0x89 in position 0: invalid start byte
# Skipping file .\images\mstile-70x70.png: 'utf-8' codec can't decode byte 0x89 in position 0: invalid start byte
# Skipping file .\images\paragraph-indent.png: 'utf-8' codec can't decode byte 0x89 in position 0: invalid start byte
# Skipping file .\images\paragraph-no-indent.png: 'utf-8' codec can't decode byte 0x89 in position 0: invalid start byte
# Skipping file .\images\pipe centering.png: 'utf-8' codec can't decode byte 0x89 in position 0: invalid start byte
# Skipping file .\images\pipe centering2.png: 'utf-8' codec can't decode byte 0x89 in position 0: invalid start byte
# Skipping file .\images\pipe centering3.png: 'utf-8' codec can't decode byte 0x89 in position 0: invalid start byte
# Skipping file .\images\profile.png: 'utf-8' codec can't decode byte 0xff in position 0: invalid start byte
# Skipping file .\images\signal communication_detection.png: 'utf-8' codec can't decode byte 0x89 in position 0: invalid start byte
# Skipping file .\images\site-logo.png: 'utf-8' codec can't decode byte 0x89 in position 0: invalid start byte
# Files containing the target string:
# .\_config.yml
# .\检查文件.ipynb
# .\.ipynb_checkpoints\检查文件-checkpoint.ipynb
